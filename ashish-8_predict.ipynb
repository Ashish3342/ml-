# %%
import numpy as np
from keras.preprocessing import image
# Out:
# Using TensorFlow backend.

# %%
from keras.models import load_model

# %%
model=load_model('class-8.h5')

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_4 (Conv2D)            (None, 98, 98, 32)        896
# _________________________________________________________________
# activation_8 (Activation)    (None, 98, 98, 32)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 49, 49, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 47, 47, 32)        9248
# _________________________________________________________________
# activation_9 (Activation)    (None, 47, 47, 32)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 23, 23, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 21, 21, 64)        18496
# ...

# %%
import matplotlib.pyplot as plt

# %%
img=image.load_img('predict/man3.jpg',target_size=(100,100))

plt.imshow(img)
plt.axis('off')
plt.show()
img_tensor=image.img_to_array(img)
img_tensor=np.expand_dims(img_tensor,axis=0)
img_tensor/=255

# %%
model.predict_classes(img_tensor)
# Out:
# array([7], dtype=int64)

# %%
img=image.load_img('predict/fruit.jpg',target_size=(100,100))

plt.imshow(img)
plt.axis('off')
plt.show()
img_tensor=image.img_to_array(img)
img_tensor=np.expand_dims(img_tensor,axis=0)
img_tensor/=255
model.predict_classes(img_tensor)
# Out:
# array([5], dtype=int64)

# %%
img=image.load_img('predict/cat.jpg',target_size=(100,100))

plt.imshow(img)
plt.axis('off')
plt.show()
img_tensor=image.img_to_array(img)
img_tensor=np.expand_dims(img_tensor,axis=0)
img_tensor/=255
model.predict_classes(img_tensor)
# Out:
# array([3], dtype=int64)

# %%
img=image.load_img('predict/cat2.jpg',target_size=(100,100))

plt.imshow(img)
plt.axis('off')
plt.show()
img_tensor=image.img_to_array(img)
img_tensor=np.expand_dims(img_tensor,axis=0)
img_tensor/=255
model.predict_classes(img_tensor)
# Out:
# array([3], dtype=int64)

# %%
img=image.load_img('predict/motor.jpg',target_size=(100,100))

plt.imshow(img)
plt.axis('off')
plt.show()
img_tensor=image.img_to_array(img)
img_tensor=np.expand_dims(img_tensor,axis=0)
img_tensor/=255
model.predict_classes(img_tensor)
# Out:
# array([6], dtype=int64)

# %%
img=image.load_img('predict/motor2.jpg',target_size=(100,100))

plt.imshow(img)
plt.axis('off')
plt.show()
img_tensor=image.img_to_array(img)
img_tensor=np.expand_dims(img_tensor,axis=0)
img_tensor/=255
model.predict_classes(img_tensor)
# Out:
# array([4], dtype=int64)

# %%
img=image.load_img('predict/flower.jpg',target_size=(100,100))

plt.imshow(img)
plt.axis('off')
plt.show()
img_tensor=image.img_to_array(img)
img_tensor=np.expand_dims(img_tensor,axis=0)
img_tensor/=255
model.predict_classes(img_tensor)
# Out:
# array([4], dtype=int64)

# %%
img=image.load_img('predict/dog.jpg',target_size=(100,100))

plt.imshow(img)
plt.axis('off')
plt.show()
img_tensor=image.img_to_array(img)
img_tensor=np.expand_dims(img_tensor,axis=0)
img_tensor/=255
model.predict_classes(img_tensor)
# Out:
# array([3], dtype=int64)

# %%
img=image.load_img('predict/dog2.jpg',target_size=(100,100))

plt.imshow(img)
plt.axis('off')
plt.show()
img_tensor=image.img_to_array(img)
img_tensor=np.expand_dims(img_tensor,axis=0)
img_tensor/=255
model.predict_classes(img_tensor)
# Out:
# array([3], dtype=int64)

# %%
img=image.load_img('predict/car.jpg',target_size=(100,100))

plt.imshow(img)
plt.axis('off')
plt.show()
img_tensor=image.img_to_array(img)
img_tensor=np.expand_dims(img_tensor,axis=0)
img_tensor/=255
model.predict_classes(img_tensor)
# Out:
# array([1], dtype=int64)

# %%
img=image.load_img('predict/plan.jpg',target_size=(100,100))

plt.imshow(img)
plt.axis('off')
plt.show()
img_tensor=image.img_to_array(img)
img_tensor=np.expand_dims(img_tensor,axis=0)
img_tensor/=255
model.predict_classes(img_tensor)
# Out:
# array([0], dtype=int64)
